# %% [markdown]
# <style>
#   /* Hate Speech — notebook theme */
#   .nb-hero {
#     background: linear-gradient(135deg, #0f172a 0%, #312e81 40%, #5b21b6 100%);
#     color: #f1f5f9;
#     padding: 1.75rem 1.5rem 1.5rem;
#     border-radius: 14px;
#     margin: 0 0 1.25rem;
#     box-shadow: 0 12px 40px rgba(15, 23, 42, 0.35);
#     font-family: ui-sans-serif, "Segoe UI", system-ui, sans-serif;
#   }
#   .nb-hero h1 { margin: 0 0 0.5rem; font-size: 1.75rem; font-weight: 700; letter-spacing: -0.02em; }
#   .nb-hero p { margin: 0; opacity: 0.92; font-size: 0.98rem; line-height: 1.5; }
#   .nb-hero .nb-sub { margin-top: 1rem; display: flex; flex-wrap: wrap; gap: 0.4rem; }
#   .nb-pill { background: rgba(255,255,255,0.12); border: 1px solid rgba(255,255,255,0.2); border-radius: 999px; padding: 0.2rem 0.75rem; font-size: 0.8rem; }
#   .nb-section { font-family: ui-sans-serif, "Segoe UI", system-ui, sans-serif; color: #0f172a; margin: 0 0 1rem; }
#   .nb-section h2 { margin: 0 0 0.75rem; font-size: 1.2rem; font-weight: 700; color: #1e1b4b; display: flex; align-items: center; gap: 0.5rem; }
#   .nb-kicker { display: inline-block; background: linear-gradient(135deg, #e0e7ff, #ede9fe); color: #4338ca; font-size: 0.7rem; font-weight: 700; letter-spacing: 0.06em; text-transform: uppercase; padding: 0.2rem 0.55rem; border-radius: 6px; }
#   .nb-card { background: #f8fafc; border: 1px solid #e2e8f0; border-radius: 10px; padding: 1rem 1.1rem; margin: 0.5rem 0; }
#   .nb-card ul { margin: 0.4rem 0 0; padding-left: 1.2rem; }
#   .nb-card li { margin: 0.25rem 0; }
#   .nb-goals { color: #475569; font-size: 0.92rem; line-height: 1.55; margin: 0.35rem 0 0.75rem; }
#   .nb-callout { border-left: 4px solid #6366f1; background: #eef2ff; padding: 0.65rem 0.9rem; border-radius: 0 8px 8px 0; font-size: 0.92rem; color: #3730a3; margin: 0.5rem 0; font-style: italic; }
#   .nb-grid-2 { display: grid; grid-template-columns: 1fr 1fr; gap: 0.75rem; margin-top: 0.5rem; }
#   @media (max-width: 700px) { .nb-grid-2 { grid-template-columns: 1fr; } }
#   .nb-compare h4 { margin: 0 0 0.35rem; font-size: 0.85rem; color: #334155; }
#   .nb-compare p, .nb-compare li { font-size: 0.86rem; color: #64748b; }
#   .nb-compare .ok { color: #059669; }
#   .nb-compare .warn { color: #d97706; }
#   .nb-embed-grid { display: grid; grid-template-columns: repeat(auto-fit, minmax(200px, 1fr)); gap: 0.6rem; margin-top: 0.5rem; }
#   .nb-embed { background: #fff; border: 1px solid #e2e8f0; border-radius: 8px; padding: 0.75rem; font-size: 0.85rem; }
#   .nb-embed h4 { margin: 0 0 0.4rem; font-size: 0.88rem; color: #0f172a; }
#   .nb-embed p { margin: 0.15rem 0; color: #64748b; line-height: 1.4; }
#   .nb-embed p:first-of-type::before { content: "✓ "; color: #6366f1; font-weight: bold; }
#   .nb-divider { text-align: center; color: #94a3b8; font-size: 0.8rem; margin: 1.25rem 0; letter-spacing: 0.2em; }
#   .nb-data { background: linear-gradient(90deg, #f0fdf4, #ecfeff); border: 1px solid #a7f3d0; border-radius: 10px; padding: 1rem 1.1rem; font-family: ui-sans-serif, system-ui, sans-serif; }
#   .nb-data h2 { margin: 0; font-size: 1.1rem; color: #14532d; }
#   .nb-data p { margin: 0.4rem 0 0; color: #166534; font-size: 0.9rem; }
#   .nb-foot { text-align: center; color: #94a3b8; font-size: 0.8rem; margin: 1.5rem 0 0.5rem; }
# </style>
#
# <div class="nb-hero">
#   <h1>Pipeline de prétraitement NLP</h1>
#   <div class="nb-sub">
#     <span class="nb-pill">Nettoyage</span>
#     <span class="nb-pill">Tokenization</span>
#     <span class="nb-pill">Stopwords</span>
#     <span class="nb-pill">Lemmatization</span>
#     <span class="nb-pill">Data</span>
#   </div>
# </div>

# %%
# %pip install numpy pandas matplotlib seaborn scikit-learn nltk gensim tqdm emoji

# %%
import nltk

nltk.download('punkt', quiet=True)
nltk.download('stopwords', quiet=True)
nltk.download('wordnet', quiet=True)
nltk.download('omw-1.4', quiet=True)
# Out:
# ...
#   Using cached emoji-2.15.0-py3-none-any.whl.metadata (5.7 kB)
# ...
#   Using cached num2words-0.5.14-py3-none-any.whl.metadata (13 kB)
# ...
#   Using cached docopt-0.6.2.tar.gz (25 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Using cached emoji-2.15.0-py3-none-any.whl (608 kB)
# Using cached num2words-0.5.14-py3-none-any.whl (163 kB)
# ...
#   Created wheel for docopt: filename=docopt-0.6.2-py2.py3-none-any.whl size=13775 sha256=0ef6c6637182d239cd3324a9c729b216faa78b823ff8922ee684785e7a2e817a
#   Stored in directory: c:\users\dell\appdata\local\pip\cache\wheels\1a\bf\a1\4cee4f7678c68c5875ca89eaccf460593539805c3906722228
# Successfully built docopt
# ...
#
#    ------------- -------------------------- 1/3 [num2words]
#    ------------- -------------------------- 1/3 [num2words]
#    ------------- -------------------------- 1/3 [num2words]
#    ------------- -------------------------- 1/3 [num2words]
# ...

# %%
# The main dataset is loaded in the next cell. NLTK resources are already available.
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Dell\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Dell\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Dell\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\Dell\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# True

# %%
# ===============================
# Core Libraries
# ===============================

import os
import re
import emoji
import numpy as np
import pandas as pd

# ===============================
# Visualization
# ===============================

import matplotlib.pyplot as plt
import seaborn as sns

# ===============================
# NLP (NLTK)
# ===============================

import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer

# ===============================
# Machine Learning
# ===============================

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics import accuracy_score, classification_report, ConfusionMatrixDisplay

# ===============================
# Vectorization Methods
# Order: Word2Vec → FastText → GloVe
# ===============================

from gensim.models import Word2Vec
from gensim.models import FastText

print("All libraries imported successfully!")
# Out:
# All libraries imported successfully!

# %%
data_path = "HateSpeechData.csv"

if not os.path.exists(data_path):
    raise FileNotFoundError(f"Dataset not found at {data_path}. Please place the file in the notebook folder.")

df = pd.read_csv(data_path)
print("Loaded dataset with shape:", df.shape)
print("Columns:", df.columns.tolist())

# %%
# Drop unnamed index columns and normalize column names
unnamed_cols = [col for col in df.columns if col.startswith("Unnamed")]
if unnamed_cols:
    df = df.drop(columns=unnamed_cols)

df.columns = [col.strip() for col in df.columns]
text_col = "tweet" if "tweet" in df.columns else df.columns[0]
label_col = "class" if "class" in df.columns else df.columns[-1]

print("Using text column:", text_col)
print("Using label column:", label_col)

df.head()
# Out:
#    Unnamed: 0  count  hate_speech  offensive_language  neither  class  \
# 0           0      3            0                   0        3      2
# 1           1      3            0                   3        0      1
# 2           2      3            0                   3        0      1
# 3           3      3            0                   2        1      1
# 4           4      6            0                   6        0      1
#
#                                                tweet
# 0  !!! RT @mayasolovely: As a woman you shouldn't...
# 1  !!!!! RT @mleew17: boy dats cold...tyga dwn ba...
# 2  !!!!!!! RT @UrKindOfBrand Dawg!!!! RT @80sbaby...
# 3  !!!!!!!!! RT @C_G_Anderson: @viva_based she lo...
# 4  !!!!!!!!!!!!! RT @ShenikaRoberts: The shit you...

# %%
print(df.info())
print("\nClass counts:")
print(df[label_col].value_counts())
print("\nClass distribution:")
print(df[label_col].value_counts(normalize=True).round(3))

# %%
plt.figure(figsize=(8, 4))
sns.countplot(data=df, x=label_col, palette="crest")
plt.title("Class Distribution")
plt.xlabel(label_col)
plt.ylabel("Count")
plt.show()
# Out:
#               count   hate_speech  offensive_language       neither  \
# count  24783.000000  24783.000000        24783.000000  24783.000000
# mean       3.243473      0.280515            2.413711      0.549247
# std        0.883060      0.631851            1.399459      1.113299
# min        3.000000      0.000000            0.000000      0.000000
# 25%        3.000000      0.000000            2.000000      0.000000
# 50%        3.000000      0.000000            3.000000      0.000000
# 75%        3.000000      0.000000            3.000000      0.000000
# max        9.000000      7.000000            9.000000      9.000000
#
#               class
# count  24783.000000
# mean       1.110277
# std        0.462089
# min        0.000000
# 25%        1.000000
# 50%        1.000000
# 75%        1.000000
# max        2.000000

# %% [markdown]
#  # 1. text cleaning

# %%
import re
import emoji

# Known hate / toxic codes as whole tokens; longest first so masking is unambiguous
hate_codes_strong = {"1488", "88", "14", "18", "28"}
hate_codes_medium = {"311", "33", "333"}
toxic_codes = {"1312", "13", "187"}
weak_codes = {"666"}
extra_preserved_codes = {"69", "911", "12", "12.666"}

PRESERVED_NUMBER_CODES = sorted(
    hate_codes_strong
    | hate_codes_medium
    | toxic_codes
    | weak_codes
    | extra_preserved_codes,
    key=len,
    reverse=True,
)
_PH_PREFIX = "__PRES_NUM_"
PRESERVED_NUMBER_CODES_SET = set(PRESERVED_NUMBER_CODES)


def _protect_preserved_number_codes(text):
    # Replace each whitelisted number (whole word) with a placeholder we restore later
    for i, code in enumerate(PRESERVED_NUMBER_CODES):
        ph = f" {_PH_PREFIX}{i}__ "
        pat = r"\b" + re.escape(code) + r"\b"
        text = re.sub(pat, ph, text)
    return text


def _restore_preserved_number_codes(text):
    # Turn placeholders back into the original digit strings
    for i, code in enumerate(PRESERVED_NUMBER_CODES):
        ph = f" {_PH_PREFIX}{i}__ "
        text = text.replace(ph, f" {code} ")
    return text


def _strip_standalone_numbers(text):
    # Drop integers/decimals that form their own "word" (digits inside b1tch stay, no \b on the middle 1)
    return re.sub(r"\b\d+(?:\.\d+)?\b", " ", text)


def process_token(token):
    # After cleaning, a numeric-only token should be a preserved code, or be dropped
    if re.fullmatch(r"\d+(?:\.\d+)?", token):
        if token in PRESERVED_NUMBER_CODES_SET:
            return token
        return ""
    return token


def clean_text(text, lang="en"):
    # lang: unused after switching from num2words; kept for a stable function signature
    if not isinstance(text, str):
        text = str(text)  # Coerce to string so the rest of the pipeline is safe
    if not text:
        return text  # Nothing to do for empty / falsy text

    text = emoji.demojize(text)  # :smile: text instead of pictographs, before we strip symbols
    text = text.lower()  # Make casing uniform for GloVe / matching

    text = re.sub(r"@\w+", " ", text)  # Remove @username mentions
    text = re.sub(r"\brt\b", " ", text)  # Remove retweet prefix as its own word

    text = _protect_preserved_number_codes(text)  # So we do not delete allowed codes next
    text = _strip_standalone_numbers(text)  # Remove other stand-alone numbers

    text = text.replace("-", " ")  # Turn hyphens (e.g. forty-two) into separable word chunks
    text = re.sub(r"[^\w\s]", "", text)  # Remove punctuation; keep word chars and whitespace

    text = _restore_preserved_number_codes(text)  # After punct so decimals like 12.666 keep the dot

    tokens = text.split()  # Whitespace tokenization
    tokens = [process_token(t) for t in tokens if t]  # drop stray number tokens
    text = " ".join(tokens)  # Single string again for later steps
    text = re.sub(r"\s+", " ", text).strip()  # One space between words, trim ends
    return text

# %%
text = "RT @user I h8 you 1488!! b1tch 2024"
print(clean_text(text))
# Out:
# i h8 you 1488 b1tch

# %% [markdown]
# # 2. tokenization

# %%
def tokenize_text(text):
    return text.split()

# %%
clean_comment = clean_text("You are STUPID!!! 😡 123")
tokenize_text(clean_comment)
# Out:
# ['you', 'are', 'stupid', 'enraged_face']

# %% [markdown]
# # 3. stopword removal

# %%
from nltk.corpus import stopwords

stop_words = set(stopwords.words('english'))

# %%
def remove_stopwords(tokens):
    return [w for w in tokens if w not in stop_words]

# %%
tokens = ["you", "are", "a", "stupid", "person"]
remove_stopwords(tokens)
# Out:
# ['stupid', 'person']

# %% [markdown]
# # 4. lemmatization

# %%
lemmatizer = WordNetLemmatizer()
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Dell\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\Dell\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!

# %%
def lemmatize_text(tokens):
    return [lemmatizer.lemmatize(w, pos='v') for w in tokens]

# %%
tokens = ["running", "hated", "better"]
lemmatize_text(tokens)
# Out:
# ['run', 'hat', 'better']

# %%
def full_preprocess(text):
    if pd.isna(text):
        return ""

    text = clean_text(text)
    tokens = tokenize_text(text)
    tokens = remove_stopwords(tokens)
    tokens = lemmatize_text(tokens)

    return " ".join(tokens)

# %%
df["cleaned_text"] = df[text_col].apply(full_preprocess)

# %%
pd.set_option('display.max_colwidth', None)

sample_output = df[[text_col, "cleaned_text", label_col]].sample(6, random_state=42)
sample_output.reset_index(drop=True, inplace=True)
sample_output
# Out:
#                                                                                                                                           tweet  \
# 0  !!! RT @mayasolovely: As a woman you shouldn't complain about cleaning up your house. &amp; as a man you should always take the trash out...
# 1                                                         !!!!! RT @mleew17: boy dats cold...tyga dwn bad for cuffin dat hoe in the 1st place!!
# 2                      !!!!!!! RT @UrKindOfBrand Dawg!!!! RT @80sbaby4life: You ever fuck a bitch and she start to cry? You be confused as shit
# 3                                                                                !!!!!!!!! RT @C_G_Anderson: @viva_based she look like a tranny
# 4     !!!!!!!!!!!!! RT @ShenikaRoberts: The shit you hear about me might be true or it might be faker than the bitch who told it to ya &#57361;
#
#                                                     cleaned_text
# ...

# %% [markdown]
# # 5. vectorization (Embedding)

# %% [markdown]
# ## Word2Vec

# %%
sentences = [
    row.split()
    for row in df["cleaned_text"].astype(str)
    if row.strip()
]

model = Word2Vec(
    sentences,
    vector_size=100,
    window=5,
    min_count=2,
    epochs=5,
)
print("Word2Vec vocabulary size:", len(model.wv))

# %%
word = "trash"

if word in model.wv:
    print("Word2Vec vector sample:", model.wv[word][:5])
else:
    print(word, "not in vocabulary")
# Out:
# [-5.6797761e-01  3.1387767e-01  3.6517438e-01  4.9477348e-01
#  -1.6105558e-01 -8.8253409e-01  1.7038091e-01  9.9043238e-01
#  -4.9740991e-01 -3.9568013e-01 -3.1269819e-01 -8.0529267e-01
#  -2.5230077e-01  1.3824628e-02  1.9470488e-01 -5.7904124e-01
#  -1.0133178e-01 -9.7413850e-01 -1.0024096e-02 -1.2865038e+00
#   5.0833446e-01  1.9907640e-01  4.7610320e-02  6.0569625e-02
#  -1.5859913e-02  1.8882285e-01 -6.1997324e-01 -6.0779405e-01
#  -6.1679089e-01 -3.9990224e-02  6.4357978e-01  5.1665807e-01
#   3.6082348e-01 -3.6560065e-01 -4.8191316e-02  4.7903323e-01
#   1.4145687e-01 -6.6163784e-01 -4.1763940e-01 -1.3653094e+00
#  -2.2117227e-01 -8.7990087e-01 -3.3232599e-01 -2.0717289e-01
#   5.1773888e-01 -3.1436196e-01 -8.4534931e-01  3.4464193e-03
#   1.7050824e-01  5.1590401e-01  4.4290373e-01 -7.0292896e-01
#  -1.1121890e-01 -2.6956022e-01 -2.2753935e-01  3.8962755e-01
#   3.4262297e-01 -2.2056978e-02 -9.8120815e-01  3.3910471e-01
# ...

# %% [markdown]
# ## FastText

# %%
fasttext_model = FastText(
    sentences,
    vector_size=100,
    window=5,
    min_count=2,
    epochs=5,
)
print("FastText vocabulary size:", len(fasttext_model.wv))

# %%
word = "trash"
if word in fasttext_model.wv:
    print("FastText vector sample:", fasttext_model.wv[word][:5])
else:
    print(word, "not in FastText vocabulary")
# Out:
# FastText: [-0.35325727  0.03385719 -0.11013759  0.55834854  0.40696362]

# %% [markdown]
# ## GloVe

# %%
# ===============================
# GloVe — Load Pretrained Vectors
# ===============================

glove_path = "glove.6B.100d.txt"

glove_embeddings = {}

if os.path.exists(glove_path):
    with open(glove_path, encoding="utf8") as f:
        for line in f:
            values = line.split()
            word = values[0]
            vector = np.asarray(values[1:], dtype="float32")
            glove_embeddings[word] = vector
    print("Loaded", len(glove_embeddings), "GloVe word vectors")
else:
    print(f"GloVe file not found at {glove_path}. Skipping GloVe embedding load.")
# Out:
# Loaded 400000 GloVe word vectors

# %%
# ===============================
# Test Word Vector
# ===============================

word = "trash"
if glove_embeddings and word in glove_embeddings:
    print("GloVe vector sample:", glove_embeddings[word][:5])
else:
    print(word, "not in GloVe vocabulary or GloVe not loaded")
# Out:
# GloVe: [-0.23076  0.4707   0.76068 -1.5495   0.2006 ]

# %% [markdown]
# # 6. TF-IDF + classification

# %% [markdown]
# ## TF-IDF (word importance)

# %%
vectorizer = TfidfVectorizer(max_features=5000, ngram_range=(1, 2))
X_tfidf = vectorizer.fit_transform(df["cleaned_text"])

y = df[label_col]
X_train, X_test, y_train, y_test = train_test_split(
    X_tfidf,
    y,
    stratify=y,
    test_size=0.20,
    random_state=42,
)

clf = LogisticRegression(max_iter=1000, random_state=42)
clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)

print("TF-IDF matrix shape:", X_tfidf.shape)
print("Test accuracy:", accuracy_score(y_test, y_pred))
print("\nClassification report:\n", classification_report(y_test, y_pred, zero_division=0))
# Out:
# TF-IDF matrix shape: (24783, 10000)

# %%
ConfusionMatrixDisplay.from_estimator(
    clf,
    X_test,
    y_test,
    cmap="Blues",
    display_labels=clf.classes_,
)
plt.title("TF-IDF + Logistic Regression Confusion Matrix")
plt.show()

feature_names = np.array(vectorizer.get_feature_names_out())
for i, class_label in enumerate(clf.classes_):
    top_idx = np.argsort(clf.coef_[i])[-10:][::-1]
    print(f"Top features for class {class_label}:")
    print(", ".join(feature_names[top_idx]))
    print()
